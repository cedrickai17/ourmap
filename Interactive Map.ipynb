# %%
import folium
import base64
import os
import pandas as pd
from github import Github

# %%
sheet_id = '1j1T54UNgcUnM80YTbwn158PfrOuGOk8C5KBiAHTaHik'
sheet_name = 'Sheet1'
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

df_google_sheet = pd.read_csv(url)
df_google_sheet
# Out:
#     Index       Lat         Lon                              Address  \
# 0       1  1.277770  103.846331                          Cafe Kremes
# 1       2  1.279340  103.846653                     Amoy Food Centre
# 2       3  1.305313  103.853338                          Paint Blush
# 3       4  1.337093  103.779074                         Kindred Folk
# 4       5  1.352792  103.886683                              Lickers
# 5       6  1.337025  103.779114                         Kindred Folk
# 6       7  1.298737  103.906031         Atmosphere Thai Bistro & Bar
# 7       8  1.337928  103.793182                           Axe Factor
# 8       9  1.281269  103.818421                          Burger Labo
# 9      10  1.308371  103.810143                            Candlenut
# 10     11  1.312464  103.925514            Five Oars Coffee Roasters
# 11     12  1.285023  103.833594             Merci Marcel Tiong Bahru
# 12     13  1.279509  103.843363                               Coucou
# 13     14  1.308865  103.822674        Nassim Hill Bakery Bistro Bar
# 14     15  1.315081  103.911031                   The Brewing Ground
# 15     16  1.346039  103.944774  Tampines Round Market & Food Centre
# 16     17  1.360527  103.953031                    Tampines Kolo Mee
#
#                  Title                                        Description  \
# 0   Long Awaited Cafe!  1st visit: we didn't manage to get a seat. 2nd...
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
# 5                  NaN                                                NaN
# 6                  NaN                                                NaN
# 7                  NaN                                                NaN
# 8                  NaN                                                NaN
# 9                  NaN                                                NaN
# 10                 NaN                                                NaN
# 11                 NaN                                                NaN
# 12                 NaN                                                NaN
# 13                 NaN                                                NaN
# 14                 NaN                                                NaN
# 15                 NaN                                                NaN
# 16                 NaN                                                NaN
#
#           Icon Colour  Img
# 0     pot-food  green  NaN
# 1   kiwi-fruit  green  NaN
# 2          NaN  green  NaN
# 3          NaN  green  NaN
# 4          NaN  green  NaN
# 5          NaN  green  NaN
# 6          NaN  green  NaN
# 7          NaN  green  NaN
# 8          NaN  green  NaN
# 9          NaN  green  NaN
# 10         NaN  green  NaN
# 11         NaN  green  NaN
# 12         NaN  green  NaN
# 13         NaN  green  NaN
# 14         NaN  green  NaN
# 15         NaN  green  NaN
# 16         NaN  green  NaN

# %%
m = folium.Map(location=[1.349551, 103.812823], tiles='CartoDB positron',zoom_start=12)

# %%
def create_marker(df):
    for i in range(0,len(df)):
        #not using this iframe for now. not sure what's its for
        #iframe = folium.IFrame(html=html,width=400,height=400)
        html = folium.Html (
                f"""
                <html>
                <h3>{df.iloc[i]['Title']}</h3>
                <p>{df.iloc[i]['Description']}'</p>
                <img src= 'beauty_1676803468093.JPG' width=100px>
                </html>
                """, script=True
            )
        marker_popup = folium.Popup(html=html, max_width=500)
        marker_tooltip = folium.Tooltip(text=df.iloc[i]['Address'],sticky=False)
        marker_icon = folium.Icon(color=df.iloc[i]['Colour'],icon=df.iloc[i]['Icon'], prefix='fa')
        #create marker from here
        folium.Marker([df.iloc[i]['Lat'],df.iloc[i]['Lon']], popup=marker_popup, tooltip=marker_tooltip, icon=marker_icon).add_to(m)

# %%
create_marker(df_google_sheet)

# %%
m.save('index.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_754d49d15cd3c1291498a04bc092d697 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_754d49d15cd3c1291498a04bc092d697&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_754d49d15cd3c1291498a04bc092d697 = L.map(
#                 &quot;map_754d49d15cd3c1291498a04bc092d697&quot;,
#                 {
#                     center: [1.349551, 103.812823],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eba767389f8eaaf2b992d1b8bd7f4a9f = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_754d49d15cd3c1291498a04bc092d697);
#
#
#             var marker_97c810a74efdd84fa94d0ea0618f91e2 = L.marker(
#                 [1.277770201, 103.8463307],
#                 {}
#             ).addTo(map_754d49d15cd3c1291498a04bc092d697);
#
#
#             var icon_cd08598720d8da5d4ebeff05589ce989 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_97c810a74efdd84fa94d0ea0618f91e2.setIcon(icon_cd08598720d8da5d4ebeff05589ce989);
#
#
#         var popup_224d622170ef110071cc4512790943bd = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_120f87deadea5b435d28e2708240e0bb = $(`&lt;div id=&quot;html_120f87deadea5b435d28e2708240e0bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                 &lt;html&gt;                 &lt;h3&gt;Long Awaited Cafe!&lt;/h3&gt;                 &lt;p&gt;1st visit: we didn&#x27;t manage to get a seat \n2nd visit: we forgot the appointment time \n3rd visit: we manage to get a seat! \n But the food in the end was so so...&#x27;&lt;/p&gt;                 &lt;img src= &#x27;beauty_1676803468093.JPG&#x27; width=100px&gt;                 &lt;/html&gt;                 &lt;/div&gt;`)[0];
#                 popup_224d622170ef110071cc4512790943bd.setContent(html_120f87deadea5b435d28e2708240e0bb);
#
#
#
#         marker_97c810a74efdd84fa94d0ea0618f91e2.bindPopup(popup_224d622170ef110071cc4512790943bd)
#         ;
#
#
#
#
#             marker_97c810a74efdd84fa94d0ea0618f91e2.bindTooltip(
#                 `&lt;div&gt;
#                      Cafe Kremes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: false}
#             );
#
#
#             var marker_5c8f18c10a895c9b5e0b2e51a0a687ad = L.marker(
#                 [1.2793399, 103.8466525],
#                 {}
#             ).addTo(map_754d49d15cd3c1291498a04bc092d697);
#
#
#             var icon_c2c151ebc7bb25428a8e4ed87f13f4b0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5c8f18c10a895c9b5e0b2e51a0a687ad.setIcon(icon_c2c151ebc7bb25428a8e4ed87f13f4b0);
#
#
#         var popup_95182314efa8fec3024e31375287711d = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_bfe2f53687bc508a2e0e726fad5c5784 = $(`&lt;div id=&quot;html_bfe2f53687bc508a2e0e726fad5c5784&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                 &lt;html&gt;                 &lt;h3&gt;nan&lt;/h3&gt;                 &lt;p&gt;nan&#x27;&lt;/p&gt;                 &lt;img src= &#x27;beauty_1676803468093.JPG&#x27; width=100px&gt;                 &lt;/html&gt;                 &lt;/div&gt;`)[0];
#                 popup_95182314efa8fec3024e31375287711d.setContent(html_bfe2f53687bc508a2e0e726fad5c5784);
#
#
#
#         marker_5c8f18c10a895c9b5e0b2e51a0a687ad.bindPopup(popup_95182314efa8fec3024e31375287711d)
#         ;
#
#
#
#
#             marker_5c8f18c10a895c9b5e0b2e51a0a687ad.bindTooltip(
#                 `&lt;div&gt;
#                      Amoy Food Centre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: false}
#             );
#
#
#             var marker_87aab0630ea16dab374574aa99b1c4d6 = L.marker(
#                 [1.305313076, 103.8533382],
#                 {}
#             ).addTo(map_754d49d15cd3c1291498a04bc092d697);
#
#
#             var icon_b252b8bae12eabdd1116d524d7984fbe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;:

# %%
#need to upload to github
g = Github('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')
repo = g.get_repo('cedrickai17/ourmap')
#get the content inside the repo
index_file = repo.get_contents('index.html')

# %%
with open('index.html', 'r') as file:
    data = file.read()

#update repo file
repo.update_file(path=index_file.path,message='updated index.html',sha=index_file.sha,content=data,branch='main')
# Out:
# {'commit': Commit(sha="af48f97bd9bd49e83186eb770af441021232bb54"),
#  'content': ContentFile(path="index.html")}
