# %%
import folium
import base64
import os
import pandas as pd
from github import Github

# %%
sheet_id = '1j1T54UNgcUnM80YTbwn158PfrOuGOk8C5KBiAHTaHik'
sheet_name = 'Sheet1'
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

df_google_sheet = pd.read_csv(url)
df_google_sheet
# Out:
#          Lat         Lon                              Address  Title  \
# 0   1.277770  103.846331                          Cafe Kremes    NaN
# 1   1.279340  103.846653                     Amoy Food Centre    NaN
# 2   1.305313  103.853338                          Paint Blush    NaN
# 3   1.337093  103.779074                         Kindred Folk    NaN
# 4   1.352792  103.886683                              Lickers    NaN
# 5   1.337025  103.779114                         Kindred Folk    NaN
# 6   1.298737  103.906031         Atmosphere Thai Bistro & Bar    NaN
# 7   1.337928  103.793182                           Axe Factor    NaN
# 8   1.281269  103.818421                          Burger Labo    NaN
# 9   1.308371  103.810143                            Candlenut    NaN
# 10  1.312464  103.925514            Five Oars Coffee Roasters    NaN
# 11  1.285023  103.833594             Merci Marcel Tiong Bahru    NaN
# 12  1.279509  103.843363                               Coucou    NaN
# 13  1.308865  103.822674        Nassim Hill Bakery Bistro Bar    NaN
# 14  1.315081  103.911031                   The Brewing Ground    NaN
# 15  1.346039  103.944774  Tampines Round Market & Food Centre    NaN
# 16  1.360527  103.953031                    Tampines Kolo Mee    NaN
#
#     Description  Icon Colour  Img
# 0           NaN   NaN    red  NaN
# 1           NaN   NaN    red  NaN
# 2           NaN   NaN    red  NaN
# 3           NaN   NaN    red  NaN
# 4           NaN   NaN    red  NaN
# 5           NaN   NaN    red  NaN
# 6           NaN   NaN    red  NaN
# 7           NaN   NaN    red  NaN
# 8           NaN   NaN    red  NaN
# 9           NaN   NaN    red  NaN
# 10          NaN   NaN    red  NaN
# 11          NaN   NaN    red  NaN
# 12          NaN   NaN    red  NaN
# 13          NaN   NaN   blue  NaN
# 14          NaN   NaN   blue  NaN
# 15          NaN   NaN   blue  NaN
# 16          NaN   NaN   blue  NaN

# %%
m = folium.Map(location=[1.349551, 103.812823], tiles='CartoDB positron',zoom_start=12)

# %%
html = folium.Html (
    f"""
    <html>
    <h3>Our Long Awaited Cafe</h3>
    <p>the ice cream was good!</p>
    <img src= 'beauty_1676803468093.JPG' width=100px>
    </html>
""", script=True
)

# %%
def create_marker(df):
    for i in range(0,len(df)):
        #not using this iframe for now. not sure what's its for
        #iframe = folium.IFrame(html=html,width=400,height=400)
        marker_popup = folium.Popup(html=html, max_width=500)
        marker_tooltip = folium.Tooltip(text=df.iloc[i]['Address'],sticky=False)
        marker_icon = folium.Icon(color="blue",icon="star", prefix='fa')
        #create marker from here
        folium.Marker([df.iloc[i]['Lat'],df.iloc[i]['Lon']], popup=marker_popup, tooltip=marker_tooltip, icon=marker_icon).add_to(m)

# %%
create_marker(df_google_sheet)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b0f0353933dbebb6fc308c50efb38dc6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b0f0353933dbebb6fc308c50efb38dc6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b0f0353933dbebb6fc308c50efb38dc6 = L.map(
#                 &quot;map_b0f0353933dbebb6fc308c50efb38dc6&quot;,
#                 {
#                     center: [1.349551, 103.812823],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77663f6182b288116592e967b42a2958 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b0f0353933dbebb6fc308c50efb38dc6);
#
#
#             var marker_ab7e767b1936c0541e3148f01acd3b25 = L.marker(
#                 [1.277770201, 103.8463307],
#                 {}
#             ).addTo(map_b0f0353933dbebb6fc308c50efb38dc6);
#
#
#             var icon_7712d8d2ca72fa26f266410e7b2cb7c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ab7e767b1936c0541e3148f01acd3b25.setIcon(icon_7712d8d2ca72fa26f266410e7b2cb7c2);
#
#
#         var popup_176a8df4bfa4f904f6405e0c6a716364 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_06fc2a67b316721e6493461b00b85aa3 = $(`&lt;div id=&quot;html_06fc2a67b316721e6493461b00b85aa3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;html&gt;     &lt;h3&gt;Our Long Awaited Cafe&lt;/h3&gt;     &lt;p&gt;the ice cream was good!&lt;/p&gt;     &lt;img src= &#x27;beauty_1676803468093.JPG&#x27; width=100px&gt;     &lt;/html&gt; &lt;/div&gt;`)[0];
#                 popup_176a8df4bfa4f904f6405e0c6a716364.setContent(html_06fc2a67b316721e6493461b00b85aa3);
#
#
#
#         marker_ab7e767b1936c0541e3148f01acd3b25.bindPopup(popup_176a8df4bfa4f904f6405e0c6a716364)
#         ;
#
#
#
#
#             marker_ab7e767b1936c0541e3148f01acd3b25.bindTooltip(
#                 `&lt;div&gt;
#                      Cafe Kremes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: false}
#             );
#
#
#             var marker_5755a23e0a35b22d91629820ff838363 = L.marker(
#                 [1.2793399, 103.8466525],
#                 {}
#             ).addTo(map_b0f0353933dbebb6fc308c50efb38dc6);
#
#
#             var icon_4567ec1b1cec1319e22c09f59cd0eaa8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5755a23e0a35b22d91629820ff838363.setIcon(icon_4567ec1b1cec1319e22c09f59cd0eaa8);
#
#
#         var popup_f2ac1d7ba2ce3569152b89a4bf4f0325 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_06fc2a67b316721e6493461b00b85aa3 = $(`&lt;div id=&quot;html_06fc2a67b316721e6493461b00b85aa3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;html&gt;     &lt;h3&gt;Our Long Awaited Cafe&lt;/h3&gt;     &lt;p&gt;the ice cream was good!&lt;/p&gt;     &lt;img src= &#x27;beauty_1676803468093.JPG&#x27; width=100px&gt;     &lt;/html&gt; &lt;/div&gt;`)[0];
#                 popup_f2ac1d7ba2ce3569152b89a4bf4f0325.setContent(html_06fc2a67b316721e6493461b00b85aa3);
#
#
#
#         marker_5755a23e0a35b22d91629820ff838363.bindPopup(popup_f2ac1d7ba2ce3569152b89a4bf4f0325)
#         ;
#
#
#
#
#             marker_5755a23e0a35b22d91629820ff838363.bindTooltip(
#                 `&lt;div&gt;
#                      Amoy Food Centre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: false}
#             );
#
#
#             var marker_815f47d44e39054984157acf67c52337 = L.marker(
#                 [1.305313076, 103.8533382],
#                 {}
#             ).addTo(map_b0f0353933dbebb6fc308c50efb38dc6);
#
#
#             var icon_2ffce870dbc9f89f263f5d793b64fbc4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_815f47d44e39054984157acf67c52337.setIcon(icon_2ffce870dbc9f89f263f5d793b64fbc4);

# %%
m.save('index.html')

# %%
#need to upload to github
g = Github('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')
repo = g.get_repo('cedrickai17/ourmap')

# %%
index_file = repo.get_contents('index.html')

# %%
with open('index.html', 'r') as file:
    data = file.read()

repo.update_file(path=index_file.path,message='updated index.html',sha=index_file.sha,content=data,branch='main')
# Out:
# {'commit': Commit(sha="7067cfc770ad076a506ec4a11d2b0053222ce90c"),
#  'content': ContentFile(path="index.html")}
